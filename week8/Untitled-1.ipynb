# %%
% pip install matplotlib as mp
% pip install pandas as pd
% pip install numpy as np
# Out:
# Running cells with '.venv (3.13.14.final.0) (Python 3.13.14)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'd:/67022063/.venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'
